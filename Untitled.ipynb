# %%
# !python app.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\praka\OneDrive\Desktop\final_chatbot\app.py", line 15, in <module>
#     engine = create_engine(
#         MYSQL_URL,
#     ...<2 lines>...
#         pool_recycle=280
#     )
#   File "<string>", line 2, in create_engine
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 602, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\dialects\mysql\pymysql.py", line 74, in import_dbapi
#     return __import__("pymysql")
# ModuleNotFoundError: No module named 'pymysql'

# %%
# !pip install pymysql
# Out:
# Access is denied.

# %%
conda install -c conda-forge pymysql
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
#
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\anaconda3

# %%
# !python app.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\praka\OneDrive\Desktop\final_chatbot\app.py", line 15, in <module>
#     engine = create_engine(
#         MYSQL_URL,
#     ...<2 lines>...
#         pool_recycle=280
#     )
#   File "<string>", line 2, in create_engine
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 602, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\dialects\mysql\pymysql.py", line 74, in import_dbapi
#     return __import__("pymysql")
# ModuleNotFoundError: No module named 'pymysql'

# %%
conda install -c conda-forge pymysql
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
#
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\anaconda3

# %%
# !python app.py
